# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import cm
# %matplotlib inline
# %config InlineBackend.figure_format='retina'
import collections
from matplotlib import rcParams
rcParams['font.family'] = 'serif'
rcParams['mathtext.fontset'] = 'dejavuserif'
rcParams['mathtext.rm'] = 'serif'
rcParams['mathtext.it'] = 'serif:italic'
rcParams['mathtext.bf'] = 'serif:bold'
rcParams['axes.titlepad'] = 12

# %%
from processing_functions import *

# %%
pertfunc_dict, pertparam_dict = load_pert('-19.0')

# %%
pertfunc_dict['03863'].shape
# Out:
# (1400, 180)

# %%
pertparam_dict['03863'].shape
# Out:
# (1400, 7)

# %%
def plot_fi_pj(i,j,threshold):
    plt.figure()
    pertfunc_dict,pertparam_dict = load_pert(threshold)
    for seed in seed_list[threshold]:
        plt.plot(pertparam_dict[seed][i*200:i*200+200,i],pertfunc_dict[seed][i*200:i*200+200,j],'.',markersize=1)

# %%
plot_fi_pj(5,2,'-20.5')
plot_fi_pj(5,2,'-21.0')

# %%
plot_fi_pj(5,93,'-20.5')
plot_fi_pj(5,93,'-21.0')

# %%
# %store -r

# %%
postcov_w21p0 = []
for seed in seed_21p0:
    postcov_w21p0.append(postcov_dict_21p0[seed]['w'])
postcov_w21p0 = np.array(postcov_w21p0)
plt.hist(np.sqrt(postcov_w21p0[:,5,5]))
# Out:
# (array([ 2.,  4.,  0.,  0.,  1.,  2.,  2.,  0.,  2.,  2.]),
#  array([ 0.24079733,  0.25127536,  0.2617534 ,  0.27223143,  0.28270947,
#          0.2931875 ,  0.30366554,  0.31414357,  0.32462161,  0.33509964,
#          0.34557768]),
#  <a list of 10 Patch objects>)

# %%
postcov_w20p5 = []
for seed in seed_20p5:
    postcov_w20p5.append(postcov_dict_20p5[seed]['w'])
postcov_w20p5 = np.array(postcov_w20p5)
plt.hist(np.sqrt(postcov_w20p5[:,5,5]))
# Out:
# (array([ 2.,  2.,  5.,  2.,  2.,  1.,  0.,  0.,  0.,  1.]),
#  array([ 0.48237389,  0.52031574,  0.5582576 ,  0.59619945,  0.63414131,
#          0.67208316,  0.71002502,  0.74796688,  0.78590873,  0.82385059,
#          0.86179244]),
#  <a list of 10 Patch objects>)

# %%
postcov_d21p0 = []
for seed in seed_21p0:
    postcov_d21p0.append(postcov_dict_21p0[seed]['d'])
postcov_d21p0 = np.array(postcov_d21p0)
plt.hist(np.sqrt(postcov_d21p0[:,5,5]))
# Out:
# (array([ 2.,  1.,  0.,  4.,  2.,  2.,  0.,  1.,  2.,  1.]),
#  array([ 0.27485709,  0.28660488,  0.29835268,  0.31010047,  0.32184826,
#          0.33359605,  0.34534385,  0.35709164,  0.36883943,  0.38058722,
#          0.39233502]),
#  <a list of 10 Patch objects>)

# %%
postcov_d20p5 = []
for seed in seed_20p5:
    postcov_d20p5.append(postcov_dict_20p5[seed]['d'])
postcov_d20p5 = np.array(postcov_d20p5)
plt.hist(np.sqrt(postcov_d20p5[:,5,5]))
# Out:
# (array([ 2.,  1.,  1.,  3.,  1.,  4.,  2.,  0.,  0.,  1.]),
#  array([ 0.51666701,  0.56160519,  0.60654336,  0.65148154,  0.69641972,
#          0.74135789,  0.78629607,  0.83123424,  0.87617242,  0.9211106 ,
#          0.96604877]),
#  <a list of 10 Patch objects>)

# %%
# %store -r

# %%
# %store
# Out:
# Stored variables and their in-db values:
# alphas_cut_19p0                    -> {'va': array([ 0.41260647,  0.32665434,  0.2086277
# alphas_cut_19p5                    -> {'va': array([ 0.53724599,  0.35353736,  0.2080467
# alphas_cut_20p0                    -> {'va': array([ 0.60749019,  0.40078947,  0.2094946
# alphas_cut_20p5                    -> {'va': array([ 0.96461448,  0.40082286,  0.4418812
# alphas_cut_21p0                    -> {'va': array([ 1.        ,  0.42539299,  0.2084996
# locfit_dict_19p0                   -> {'60782': {'va': array([[  6.11666037e-03,   7.851
# locfit_dict_19p5                   -> {'16884': {'va': array([[ -1.37773908e-03,  -1.127
# locfit_dict_20p0                   -> {'25333': {'va': array([[  2.74561638e-04,   4.108
# locfit_dict_20p5                   -> {'05753': {'va': array([[  9.36731037e-04,   1.020
# locfit_dict_21p0                   -> {'35187': {'va': array([[  5.32637709e-04,   6.374
# ...

# %%
def plot_dfdp(locfitdict,key,i,color,label):
    l = 1
    for seed in locfitdict.keys():
        print locfitdict[seed][key][i],seed
        """
        if l:
            plt.plot(locfitdict[seed][key][i],'.',c=color,label=label)
            l = 0
        else:
            plt.plot(locfitdict[seed][key][i],'.',c=color)"""

# %%
plot_dfdp(locfit_dict_21p0,'w',5,'r','eee')
# Out:
# [  6.84224455e-29   1.03899278e+02   9.63060136e+00  -3.53795408e+01
#    1.31653926e+01  -1.37373764e+00   3.17874514e-01  -2.60850821e+01
#    3.32450003e+01  -2.19241988e+00   1.12387708e+01   6.03441719e+00
#    3.24644785e+00   5.71870743e+00   7.79931467e+00   5.08731123e+00
#    7.93500764e+00   3.58999475e+00   1.80397999e+00   3.61837001e+00
#    1.10791377e+00   2.24469336e+00   6.85070564e-01   1.23893003e+00
#   -6.11301194e-01   6.54393766e-01  -2.29854593e-01  -7.07400658e-01
#   -5.62302162e-01  -4.13553930e-01] 35187
# [  1.79260129e-29   4.04105914e+00   1.98518833e+01   3.88786022e+01
#   -1.01848883e+01   1.58553224e+01   8.52885520e-01  -2.20108571e+01
#   -4.29569871e+00  -6.01394833e+00   1.50500708e+01   5.16277191e+00
#    1.88069521e+01   3.46280571e+00   1.05305635e+01   9.92563622e+00
#    6.82282332e+00   3.64514853e+00   6.01600553e+00   3.63257744e+00
#    2.90607861e+00   2.67750958e+00   2.44998339e+00   9.45291338e-01
# ...

# %%
pertfunc_dict,pertparam_dict = load_pert('-21.0')
i,j = 5,1
plt.plot(pertparam_dict['35187'][i*200:i*200+200,i],pertfunc_dict['35187'][i*200:i*200+200,j],'bo',markersize=1,label='slope=104')
plt.plot(pertparam_dict['14089'][i*200:i*200+200,i],pertfunc_dict['14089'][i*200:i*200+200,j],'ro',markersize=1,label='slope=-51')
plt.legend()

# %%
from scipy.interpolate import interp1d
from scipy.interpolate import UnivariateSpline

# %%
def average_f_p(threshold,i,j,pi_range):
    pertfunc_dict,pertparam_dict = load_pert(threshold)
    mean_f = []
    for seed in seed_list[threshold]:
        x = pertparam_dict[seed][200*i:200*i+200,i]
        y = pertfunc_dict[seed][200*i:200*i+200,j]
        f = interp1d(x, y)
        mean_f.append(f(pi_range))
    mean_f = mean_of_list(mean_f)
    #median_f = np.median(np.array(mean_f),axis=0)
    return mean_f

# %%
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-21.0',5,1,np.linspace(-0.5,0.5,201))-average_f_p('-21.0',5,1,0),label='-21.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.5',5,1,np.linspace(-0.5,0.5,201))-average_f_p('-20.5',5,1,0),label='-20.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.0',5,1,np.linspace(-0.5,0.5,201))-average_f_p('-20.0',5,1,0),label='-20.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.5',5,1,np.linspace(-0.5,0.5,201))-average_f_p('-19.5',5,1,0),label='-19.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.0',5,1,np.linspace(-0.5,0.5,201))-average_f_p('-19.0',5,1,0),label='-19.0')
plt.xlabel('Acen')
plt.ylabel('<dwp[1]>')
plt.legend()

# %%
def average_f_spline(threshold,i,j,pi_range):
    pertfunc_dict,pertparam_dict = load_pert(threshold)
    mean_f = []
    for seed in seed_list[threshold]:
        x = pertparam_dict[seed][200*i:200*i+200,i]
        y = pertfunc_dict[seed][200*i:200*i+200,j]
        f = UnivariateSpline(x, y)
        f.set_smoothing_factor(2000)
        mean_f.append(f(pi_range))
    mean_f = mean_of_list(mean_f)
    #median_f = np.median(np.array(mean_f),axis=0)
    return mean_f

# %%
plt.plot(np.linspace(-0.5,0.5,201),average_f_spline('-21.0',5,1,np.linspace(-0.5,0.5,201))-average_f_spline('-21.0',5,1,0),label='-21.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_spline('-20.5',5,1,np.linspace(-0.5,0.5,201))-average_f_spline('-20.5',5,1,0),label='-20.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_spline('-20.0',5,1,np.linspace(-0.5,0.5,201))-average_f_spline('-20.0',5,1,0),label='-20.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_spline('-19.5',5,1,np.linspace(-0.5,0.5,201))-average_f_spline('-19.5',5,1,0),label='-19.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_spline('-19.0',5,1,np.linspace(-0.5,0.5,201))-average_f_spline('-19.0',5,1,0),label='-19.0')
plt.xlabel('Acen')
plt.ylabel('<dwp[1]>')
plt.legend()

# %%
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-21.0',5,2,np.linspace(-0.5,0.5,201))-average_f_p('-21.0',5,2,0),label='-21.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.5',5,2,np.linspace(-0.5,0.5,201))-average_f_p('-20.5',5,2,0),label='-20.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.0',5,2,np.linspace(-0.5,0.5,201))-average_f_p('-20.0',5,2,0),label='-20.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.5',5,2,np.linspace(-0.5,0.5,201))-average_f_p('-19.5',5,2,0),label='-19.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.0',5,2,np.linspace(-0.5,0.5,201))-average_f_p('-19.0',5,2,0),label='-19.0')
plt.xlabel('Acen')
plt.ylabel('<dwp[2]>')
plt.legend()

# %%
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-21.0',5,7,np.linspace(-0.5,0.5,201))-average_f_p('-21.0',5,7,0),label='-21.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.5',5,7,np.linspace(-0.5,0.5,201))-average_f_p('-20.5',5,7,0),label='-20.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.0',5,7,np.linspace(-0.5,0.5,201))-average_f_p('-20.0',5,7,0),label='-20.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.5',5,7,np.linspace(-0.5,0.5,201))-average_f_p('-19.5',5,7,0),label='-19.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.0',5,7,np.linspace(-0.5,0.5,201))-average_f_p('-19.0',5,7,0),label='-19.0')
plt.xlabel('Acen')
plt.ylabel('<dwp[7]>')
plt.legend()

# %%
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-21.0',5,30,np.linspace(-0.5,0.5,201))-average_f_p('-21.0',5,30,0),label='-21.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.5',5,30,np.linspace(-0.5,0.5,201))-average_f_p('-20.5',5,30,0),label='-20.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-20.0',5,30,np.linspace(-0.5,0.5,201))-average_f_p('-20.0',5,30,0),label='-20.0')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.5',5,30,np.linspace(-0.5,0.5,201))-average_f_p('-19.5',5,30,0),label='-19.5')
plt.plot(np.linspace(-0.5,0.5,201),average_f_p('-19.0',5,30,np.linspace(-0.5,0.5,201))-average_f_p('-19.0',5,30,0),label='-19.0')
plt.xlabel('Acen')
plt.ylabel('<ddeltasigma[1]>')
plt.legend()

# %%
plot_dfdp(locfit_dict_19p0,'w',0,'r','-19.0')
plot_dfdp(locfit_dict_19p5,'w',0,'b','-19.5')
plot_dfdp(locfit_dict_20p0,'w',0,'g','-20.0')
plot_dfdp(locfit_dict_20p5,'w',0,'y','-20.5')
plot_dfdp(locfit_dict_21p0,'w',0,'c','-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dalpha')

# %%
plot_dfdp(locfit_dict_19p0,'w',1,'r','-19.0')
plot_dfdp(locfit_dict_19p5,'w',1,'b','-19.5')
plot_dfdp(locfit_dict_20p0,'w',1,'g','-20.0')
plot_dfdp(locfit_dict_20p5,'w',1,'y','-20.5')
plot_dfdp(locfit_dict_21p0,'w',1,'c','-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dlogM1')

# %%
plot_dfdp(locfit_dict_19p0,'w',5,'r','-19.0')
plot_dfdp(locfit_dict_19p5,'w',5,'b','-19.5')
plot_dfdp(locfit_dict_20p0,'w',5,'g','-20.0')
plot_dfdp(locfit_dict_20p5,'w',5,'y','-20.5')
#plot_dfdp(locfit_dict_21p0,'w',5,'c')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dAcen')
plt.axhline(0,c='k')

# %%
plot_dfdp(locfit_dict_19p0,'w',5,'r','-19.0')
plot_dfdp(locfit_dict_19p5,'w',5,'b','-19.5')
plot_dfdp(locfit_dict_20p0,'w',5,'g','-20.0')
plot_dfdp(locfit_dict_20p5,'w',5,'y','-20.5')
plot_dfdp(locfit_dict_21p0,'w',5,'c','-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dAcen')
plt.axhline(0,c='k')

# %%
keylist = ['w','d','v','c','a','r','wd','wv','wc','wa','wr','dv','dc','da','dr','vc','va','vr','ca','cr','ar',\
        'wdv','wdc','wda','wdr','wvc','wva','wvr','wca','wcr','war','dvc','dva','dvr','dca','dcr','dar',\
         'vca','vcr','var','car','wdvc','wdva','wdvr','wdca','wdcr','wdar','wvca','wvcr','wvar','wcar',\
        'dvca','dvcr','dvar','dcar','vcar','wdvca','wdvcr','wdvar','wdcar','wvcar','dvcar','wdvcar']
def bundle_locfit_mean(locfit_dict,seeds):
    locfit_bundle_mean = {}
    for k in keylist:
        temp = []
        for seed in seeds:
            temp.append(locfit_dict[seed][k])
        locfit_bundle_mean[k] = mean_of_list(temp)
    return locfit_bundle_mean

# %%
mean_locfit_dict_19p0 = bundle_locfit_mean(locfit_dict_19p0,locfit_dict_19p0.keys())
mean_locfit_dict_19p5 = bundle_locfit_mean(locfit_dict_19p5,locfit_dict_19p5.keys())
mean_locfit_dict_20p0 = bundle_locfit_mean(locfit_dict_20p0,locfit_dict_20p0.keys())
mean_locfit_dict_20p5 = bundle_locfit_mean(locfit_dict_20p5,locfit_dict_20p5.keys())
mean_locfit_dict_21p0 = bundle_locfit_mean(locfit_dict_21p0,locfit_dict_21p0.keys())

# %%
plt.plot(mean_locfit_dict_19p0['w'][5],'r',label='-19.0')
plt.plot(mean_locfit_dict_19p5['w'][5],'b',label='-19.5')
plt.plot(mean_locfit_dict_20p0['w'][5],'g',label='-20.0')
plt.plot(mean_locfit_dict_20p5['w'][5],'y',label='-20.5')
plt.plot(mean_locfit_dict_21p0['w'][5],'c',label='-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dAcen')
plt.axhline(0,c='k')

# %%
plt.plot(mean_locfit_dict_19p0['d'][5],'r',label='-19.0')
plt.plot(mean_locfit_dict_19p5['d'][5],'b',label='-19.5')
plt.plot(mean_locfit_dict_20p0['d'][5],'g',label='-20.0')
plt.plot(mean_locfit_dict_20p5['d'][5],'y',label='-20.5')
plt.plot(mean_locfit_dict_21p0['d'][5],'c',label='-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dds/dAcen')
plt.axhline(0,c='k')

# %%
plt.plot(mean_locfit_dict_19p0['v'][5],'r',label='-19.0')
plt.plot(mean_locfit_dict_19p5['v'][5],'b',label='-19.5')
plt.plot(mean_locfit_dict_20p0['v'][5],'g',label='-20.0')
plt.plot(mean_locfit_dict_20p5['v'][5],'y',label='-20.5')
plt.plot(mean_locfit_dict_21p0['v'][5],'c',label='-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dvpf/dAcen')
plt.axhline(0,c='k')

# %%
plt.plot(mean_locfit_dict_19p0['c'][5],'r',label='-19.0')
plt.plot(mean_locfit_dict_19p5['c'][5],'b',label='-19.5')
plt.plot(mean_locfit_dict_20p0['c'][5],'g',label='-20.0')
plt.plot(mean_locfit_dict_20p5['c'][5],'y',label='-20.5')
plt.plot(mean_locfit_dict_21p0['c'][5],'c',label='-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dcic/dAcen')
plt.axhline(0,c='k')

# %%
plt.plot(mean_locfit_dict_19p0['a'][5],'r',label='-19.0')
plt.plot(mean_locfit_dict_19p5['a'][5],'b',label='-19.5')
plt.plot(mean_locfit_dict_20p0['a'][5],'g',label='-20.0')
plt.plot(mean_locfit_dict_20p5['a'][5],'y',label='-20.5')
plt.plot(mean_locfit_dict_21p0['a'][5],'c',label='-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dcia/dAcen')
plt.axhline(0,c='k')

# %%
plt.plot(mean_locfit_dict_19p0['r'][5],'r',label='-19.0')
plt.plot(mean_locfit_dict_19p5['r'][5],'b',label='-19.5')
plt.plot(mean_locfit_dict_20p0['r'][5],'g',label='-20.0')
plt.plot(mean_locfit_dict_20p5['r'][5],'y',label='-20.5')
plt.plot(mean_locfit_dict_21p0['r'][5],'c',label='-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dratio/dAcen')
plt.axhline(0,c='k')

# %%
plot_fi_pj(5,1,'-20.5')
plt.ylabel('wp[1]')
plt.xlabel('Acen')
plt.title('-20.5')
plot_fi_pj(5,1,'-21.0')
plt.ylabel('wp[1]')
plt.xlabel('Acen')
plt.title('-21.0')

# %%
plot_dfdp(locfit_dict_19p0,'w',6,'r','-19.0')
plot_dfdp(locfit_dict_19p5,'w',6,'b','-19.5')
plot_dfdp(locfit_dict_20p0,'w',6,'g','-20.0')
plot_dfdp(locfit_dict_20p5,'w',6,'y','-20.5')
#plot_dfdp(locfit_dict_21p0,'w',6,'c','-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dAsat')
plt.axhline(0,c='k')

# %%
plot_dfdp(locfit_dict_19p0,'w',6,'r','-19.0')
plot_dfdp(locfit_dict_19p5,'w',6,'b','-19.5')
plot_dfdp(locfit_dict_20p0,'w',6,'g','-20.0')
plot_dfdp(locfit_dict_20p5,'w',6,'y','-20.5')
plot_dfdp(locfit_dict_21p0,'w',6,'c','-21.0')
plt.xlim(0.5,30)
plt.legend()
plt.title('dwp/dAsat')
plt.axhline(0,c='k')

# %%
plot_fi_pj(6,1,'-20.5')
plt.ylabel('wp[1]')
plt.xlabel('Asat')
plt.title('-20.5')
plot_fi_pj(6,1,'-21.0')
plt.ylabel('wp[1]')
plt.xlabel('Asat')
plt.title('-21.0')

# %%
param_list = [r'$\alpha$', r'$\log{M_\mathrm{1}}$', r'$\sigma_{\log{M}}$', r'$\log{M_\mathrm{0}}$', r'$\log{M_{\rm{min}}}$',\
              r'$A_{\rm{cen}}$', r'$A_{\rm{sat}}$']

r_wp = np.logspace(-1,1.5,30)
r_wp = (r_wp[1:]+r_wp[:-1])/2.

r_ds = np.logspace(-1,1.5,31)
r_ds = np.sqrt(0.5*(r_ds[1:]**2 + r_ds[:-1]**2))

r_vpf = np.logspace(0,1,30)

cic_bin = np.concatenate([np.arange(10),np.around(np.logspace(1,np.log10(150),30-10)).astype(np.int)])
cia_bin = np.concatenate([np.arange(10),np.around(np.logspace(1,np.log10(200),30-10)).astype(np.int)])

ratio_bin = (np.linspace(0,1,31)[1:]+np.linspace(0,1,31)[:-1])/2.

# %%
for i in range(31):
    print np.linspace(0,1,31)[i]
# Out:
# 0.0
# 0.0333333333333
# 0.0666666666667
# 0.1
# 0.133333333333
# 0.166666666667
# 0.2
# 0.233333333333
# 0.266666666667
# 0.3
# 0.333333333333
# 0.366666666667
# 0.4
# 0.433333333333
# 0.466666666667
# 0.5
# 0.533333333333
# 0.566666666667
# 0.6
# 0.633333333333
# 0.666666666667
# 0.7
# 0.733333333333
# 0.766666666667
# 0.8
# 0.833333333333
# 0.866666666667
# 0.9
# 0.933333333333
# 0.966666666667
# 1.0

# %%
1  & N/A ($\ngal$) & $\rp=0.11\Mpch$ & $r=1.00\Mpch$ & $\Ncic=0$ & $\Ncia=0$ & $0.000 \leq N_2/N_5<0.033$ \\
2  & $\rp=0.11\Mpch$ & $\rp=0.13\Mpch$ & $r=1.08\Mpch$ & $\Ncic=1$ & $\Ncia=1$ & $0.033 \leq N_2/N_5<0.067$ \\
3  & $\rp=0.14\Mpch$ & $\rp=0.16\Mpch$ & $r=1.17\Mpch$ & $\Ncic=2$ & $\Ncia=2$ & $0.067 \leq N_2/N_5<0.100$ \\
4  & $\rp=0.17\Mpch$ & $\rp=0.20\Mpch$ & $r=1.27\Mpch$ & $\Ncic=3$ & $\Ncia=3$ & $0.100 \leq N_2/N_5<0.133$ \\
5  & $\rp=0.20\Mpch$ & $\rp=0.24\Mpch$ & $r=1.37\Mpch$ & $\Ncic=4$ & $\Ncia=4$ & $0.133 \leq N_2/N_5<0.167$ \\
6  & $\rp=0.25\Mpch$ & $\rp=0.29\Mpch$ & $r=1.49\Mpch$ & $\Ncic=5$ & $\Ncia=5$ & $0.167 \leq N_2/N_5<0.200$ \\
7  & $\rp=0.30\Mpch$ & $\rp=0.35\Mpch$ & $r=1.61\Mpch$ & $\Ncic=6$ & $\Ncia=6$ & $0.200 \leq N_2/N_5<0.233$ \\
8  & $\rp=0.37\Mpch$ & $\rp=0.43\Mpch$ & $r=1.74\Mpch$ & $\Ncic=7$ & $\Ncia=7$ & $0.233 \leq N_2/N_5<0.267$ \\
9  & $\rp=0.45\Mpch$ & $\rp=0.52\Mpch$ & $r=1.89\Mpch$ & $\Ncic=8$ & $\Ncia=8$ & $0.267 \leq N_2/N_5<0.300$ \\
10 & $\rp=0.54\Mpch$ & $\rp=0.62\Mpch$ & $r=2.04\Mpch$ & $\Ncic=9$ & $\Ncia=9$ & $0.300 \leq N_2/N_5<0.333$ \\
11 & $\rp=0.66\Mpch$ & $\rp=0.76\Mpch$ & $r=2.21\Mpch$ & $10 \leq \Ncic < 12$ & $10 \leq \Ncia < 12$ & $0.333 \leq N_2/N_5<0.367$ \\
12 & $\rp=0.81\Mpch$ & $\rp=0.92\Mpch$ & $r=2.40\Mpch$ & $12 \leq \Ncic < 13$ & $12 \leq \Ncia < 14$ & $0.367 \leq N_2/N_5<0.400$ \\
13 & $\rp=0.99\Mpch$ & $\rp=1.11\Mpch$ & $r=2.59\Mpch$ & $13 \leq \Ncic < 15$ & $14 \leq \Ncia < 16$ & $0.400 \leq N_2/N_5<0.433$ \\
14 & $\rp=1.20\Mpch$ & $\rp=1.35\Mpch$ & $r=2.81\Mpch$ & $15 \leq \Ncic < 18$ & $16 \leq \Ncia < 19$ & $0.433 \leq N_2/N_5<0.467$ \\
15 & $\rp=1.47\Mpch$ & $\rp=1.63\Mpch$ & $r=3.04\Mpch$ & $18 \leq \Ncic < 20$ & $19 \leq \Ncia < 22$ & $0.467 \leq N_2/N_5<0.500$ \\
16 & $\rp=1.79\Mpch$ & $\rp=1.98\Mpch$ & $r=3.29\Mpch$ & $20 \leq \Ncic < 24$ & $22 \leq \Ncia < 26$ & $0.500 \leq N_2/N_5<0.533$ \\
17 & $\rp=2.18\Mpch$ & $\rp=2.39\Mpch$ & $r=3.56\Mpch$ & $24 \leq \Ncic < 27$ & $26 \leq \Ncia < 30$ & $0.533 \leq N_2/N_5<0.567$ \\
18 & $\rp=2.66\Mpch$ & $\rp=2.90\Mpch$ & $r=3.86\Mpch$ & $27 \leq \Ncic < 31$ & $30 \leq \Ncia < 35$ & $0.567 \leq N_2/N_5<0.600$ \\
19 & $\rp=3.24\Mpch$ & $\rp=3.51\Mpch$ & $r=4.18\Mpch$ & $31 \leq \Ncic < 36$ & $35 \leq \Ncia < 41$ & $0.600 \leq N_2/N_5<0.633$ \\
20 & $\rp=3.95\Mpch$ & $\rp=4.26\Mpch$ & $r=4.52\Mpch$ & $36 \leq \Ncic < 42$ & $41 \leq \Ncia < 48$ & $0.633 \leq N_2/N_5<0.667$ \\
21 & $\rp=4.82\Mpch$ & $\rp=5.16\Mpch$ & $r=4.89\Mpch$ & $42 \leq \Ncic < 48$ & $48 \leq \Ncia < 57$ & $0.667 \leq N_2/N_5<0.700$ \\
22 & $\rp=5.88\Mpch$ & $\rp=6.25\Mpch$ & $r=5.30\Mpch$ & $48 \leq \Ncic < 55$ & $57 \leq \Ncia < 66$ & $0.700 \leq N_2/N_5<0.733$ \\
23 & $\rp=7.17\Mpch$ & $\rp=7.57\Mpch$ & $r=5.74\Mpch$ & $55 \leq \Ncic < 64$ & $66 \leq \Ncia < 78$ & $0.733 \leq N_2/N_5<0.767$ \\
24 & $\rp=8.75\Mpch$ & $\rp=9.17\Mpch$ & $r=6.21\Mpch$ & $64 \leq \Ncic < 74$ & $78 \leq \Ncia < 91$ & $0.767 \leq N_2/N_5<0.800$ \\
25 & $\rp=10.6\Mpch$ &$\rp=11.11\Mpch$ & $r=6.72\Mpch$ & $74 \leq \Ncic < 85$ & $91 \leq \Ncia < 106$ & $0.800 \leq N_2/N_5<0.833$ \\
26 & $\rp=13.0\Mpch$ &$\rp=13.46\Mpch$ & $r=7.28\Mpch$ & $85 \leq \Ncic < 98$ & $106 \leq \Ncia < 125$ & $0.833 \leq N_2/N_5<0.867$ \\
27 & $\rp=15.8\Mpch$ &$\rp=16.30\Mpch$ & $r=7.89\Mpch$ & $98 \leq \Ncic < 113$ & $125 \leq \Ncia < 146$ & $0.867 \leq N_2/N_5<0.900$ \\
28 & $\rp=19.3\Mpch$ &$\rp=19.75\Mpch$ & $r=8.53\Mpch$ & $113 \leq \Ncic < 130$ & $146 \leq \Ncia < 171$ & $0.900 \leq N_2/N_5<0.933$ \\
29 & $\rp=23.6\Mpch$ &$\rp=23.93\Mpch$ & $r=9.24\Mpch$ & $130 \leq \Ncic < 150$ & $171 \leq \Ncia < 200$ & $0.933 \leq N_2/N_5<0.967$ \\
30 & $\rp=28.7\Mpch$ &$\rp=28.99\Mpch$ & $r=10.00\Mpch$ & $\Ncic \geq 150$ & $\Ncia \geq 200$ & $0.967 \leq N_2/N_5<1.000$ \\

# %%
np.histogram([1,2,3,1,2],bins=[1,2,3])
# Out:
# (array([2, 3]), array([1, 2, 3]))
